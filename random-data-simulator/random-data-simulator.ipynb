# %% [markdown]
# ### Project 8: Random Data Simulator

# %%
import numpy as np
data = np.random.randint(100, size = (1,100))
average = data.mean()
deviation = data.std()
print(data)
print('Mean is :' , average)
print('Standard deviation is :' , deviation)
# Out:
# [[51 95  7 91 48 94 32 33 70 95 13 41 73 34 98 44 10 38 80 46  8 53 44 66
#   17 29 43 13 17 45  4 18 40 89 94 75 46  7 19 85 45  1 76  7 67 47 78 21
#   38  2 75 88 63 64 28 96 21 62 71 14 71  6 65 75 69 49  9 23 55 35 10 33
#   72 93 30 46 56 67  0 49 58 54 68 23 39 29 95 85  8 36 82 38 55 68  2 45
#   73 49 29 14]]
# Mean is : 47.32
# Standard deviation is : 27.99281336343312
